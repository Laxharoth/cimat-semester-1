# %%
import numpy as np
import matplotlib.pyplot as plt
import read_vec as red

# %%
xs = red.read_vec('vec_out/xs.vec')
realx = red.read_vec('vec_out/fn1xs_point1000.vec')
realy = red.read_vec('vec_out/fn1ys_point1000.vec')

# %%
ys = red.read_vec('vec_out/fn1line_ys1000.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/fn1poly1_ys1000.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/fn1fns_ys1000.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/fn1poli2_ys1000.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/fn1lagr_ys1000.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/fn1newt_ys1000.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')
