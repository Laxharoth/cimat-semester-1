# %%
import numpy as np
import matplotlib.pyplot as plt
import read_vec as red

# %%
xs = red.read_vec('vec_out/xs.vec')
realx = np.array([1,2,3,4,5,6])
realy = np.array([2,4,8,16,25,36])

# %%
ys = red.read_vec('vec_out/line_ys.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/poly1_ys.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/fns_ys.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/poli2_ys.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/lagr_ys.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/newt_ys.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')
