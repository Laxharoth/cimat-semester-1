# %%
import numpy as np
import matplotlib.pyplot as plt
import read_vec as red

# %%
xs = red.read_vec('vec_out/xs.vec')
realx = red.read_vec('vec_out/fn2xs_point100.vec')
realy = red.read_vec('vec_out/fn2ys_point100.vec')

# %%
ys = red.read_vec('vec_out/fn2line_ys100.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/fn2poly1_ys100.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/fn2fns_ys100.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/fn2poli2_ys100.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/fn2lagr_ys100.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')

# %%
ys = red.read_vec('vec_out/fn2newt_ys100.vec')
plt.plot(xs, ys)
plt.plot(realx, realy, 'ro')
